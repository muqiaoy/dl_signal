# %%
import torch
from torch import nn

# %%
input = torch.randn(20, 5, 10, 10) * 10000
input
# Out:
# tensor([[[[-1.3445e+04,  3.0458e+04, -9.5881e+03,  ..., -1.3200e+04,
#            -7.6551e+02,  1.2407e+04],
#           [ 4.0380e+03, -2.2717e+03, -1.8470e+04,  ..., -1.3532e+04,
#             1.4274e+04,  6.2080e+03],
#           [ 1.0533e+04,  1.0130e+04,  9.5359e+03,  ..., -3.4342e+03,
#             4.0503e+03,  5.8120e+02],
#           ...,
#           [-2.8693e+03, -9.2502e+02, -7.6535e+03,  ...,  2.7116e+03,
#             3.9834e+03,  6.2215e+02],
#           [ 1.4547e+04, -6.6141e+03,  1.0379e+03,  ...,  1.4685e+04,
#             5.7115e+03,  7.1946e+02],
#           [-2.8700e+03, -8.3200e+03, -1.9337e+04,  ..., -8.4068e+03,
#            -1.9171e+04,  8.4666e+03]],
#
#          [[-5.9644e+03, -1.6656e+04, -3.2415e+02,  ...,  5.9472e+03,
#            -1.5230e+04, -1.5891e+02],
#           [-9.6787e+03,  6.9765e+02,  5.6368e+03,  ..., -8.2331e+03,
#             1.9423e+04, -7.0689e+03],
#           [-7.5616e+03,  3.7565e+03, -4.6486e+03,  ...,  1.6201e+04,
# ...

# %%
m = nn.LayerNorm(10)

# %%
output = m(input)
output
# Out:
# tensor([[[[-8.2587e-01,  2.4270e+00, -5.4014e-01,  ..., -8.0774e-01,
#             1.1357e-01,  1.0895e+00],
#           [ 9.6564e-01,  4.1520e-01, -9.9787e-01,  ..., -5.6711e-01,
#             1.8586e+00,  1.1549e+00],
#           [ 1.0115e+00,  9.7125e-01,  9.1184e-01,  ..., -3.8453e-01,
#             3.6355e-01,  1.6816e-02],
#           ...,
#           [-3.5509e-01, -8.0163e-02, -1.0316e+00,  ...,  4.3407e-01,
#             6.1391e-01,  1.3862e-01],
#           [ 1.2732e+00, -1.2297e+00, -3.2463e-01,  ...,  1.2894e+00,
#             2.2813e-01, -3.6229e-01],
#           [ 3.0973e-02, -4.2471e-01, -1.3458e+00,  ..., -4.3197e-01,
#            -1.3319e+00,  9.7883e-01]],
#
#          [[-1.6613e-01, -1.5987e+00,  5.8959e-01,  ...,  1.4299e+00,
#            -1.4076e+00,  6.1173e-01],
#           [-1.0638e+00,  8.6490e-02,  6.3403e-01,  ..., -9.0353e-01,
#             2.1623e+00, -7.7448e-01],
#           [-8.7652e-01,  1.1228e-01, -6.2202e-01,  ...,  1.1995e+00,
# ...
