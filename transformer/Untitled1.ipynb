# %%
import torch
from torch import nn
import numpy as np
import os
from transformer.Dataset import SignalDataset_iq_fnn
from models import FNN_crelu
from models import eval_FNN
import argparse
import shutil

def save_checkpoint(state, is_best, filename='checkpoint.pth.tar'):
    torch.save(state, filename)
    if is_best:
        shutil.copyfile(filename, 'model_best.pth.tar')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-1c1ba576304e> in <module>
#       4 import os
#       5 from Dataset import SignalDataset_iq_fnn
# ----> 6 from models import FNN_crelu
#       7 from models import eval_FNN
#       8 import argparse
#
# ModuleNotFoundError: No module named 'models'
